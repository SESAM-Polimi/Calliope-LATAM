# %% [markdown]
# ![sesam_logo-4.png](attachment:sesam_logo-4.png)

# %% [markdown]
# ## Python Script to Run Calliope Models

# %% [markdown]
# ### 1. Importing calliope model and built-in cal-graph module for post-process analysis

# %%
import calliope

# %% [markdown]
# ### 2. Setting the level of verbosity of Calliope's operations

# %%
try:
    calliope.set_log_level('Error')
except:
    calliope.set_log_verbosity('Error')

# %% [markdown]
# ### 3. Assigning a name to the model settings file and run it

# %%
model = calliope.Model('Model.yaml')
model.run()
# Out:
# [2023-03-29 15:22:16] INFO     Loading sets
# [2023-03-29 15:22:16] INFO     Loading parameters
# [2023-03-29 15:22:16] INFO     constraints are loaded in the following order: ['capacity', 'dispatch', 'policy', 'energy_balance', 'costs', 'network', 'conversion', 'group', 'conversion_plus', 'export', 'milp']
# [2023-03-29 15:22:16] INFO     creating capacity constraints
# [2023-03-29 15:22:16] INFO     creating dispatch constraints
# [2023-03-29 15:22:16] INFO     creating policy constraints
# [2023-03-29 15:22:16] INFO     creating energy_balance constraints
# [2023-03-29 15:22:16] INFO     creating costs constraints
# [2023-03-29 15:22:17] INFO     creating network constraints
# [2023-03-29 15:22:17] INFO     creating conversion constraints
# [2023-03-29 15:22:17] INFO     creating group constraints
# [2023-03-29 15:22:17] INFO     creating conversion_plus constraints
# [2023-03-29 15:22:17] INFO     creating export constraints
# ...

# %% [markdown]
# ### 4. Saving the input data and output results in separated csv files

# %%
model.to_csv(r'Risultati2021')

# %% [markdown]
# ### 5. Creating an instance of the built-in graph class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

idx = pd.IndexSlice

#%% DEMAND 


demand_SAPP = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,:,'demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

demand_BENR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'BENR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_LPZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_SCZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_ORUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_POTR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_CHUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
demand_TAJR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR','demand_power',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

#%% PRODUCTION BASE 

OCGT_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
CCGT_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,['CCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Dual_Fuel_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,['Dual_Fuel_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
ICE_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'ICE_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Bio_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Bio_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Small_hydro_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Small_hydro_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Large_hydro_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Large_hydro_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Wind_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Wind_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Solar_pp_oruro_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Solar_pp_oruro',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Solar_pp_yunchara_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Solar_pp_yunchara',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Solar_pp_uyuni_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Solar_pp_uyuni',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Nuclear_pp_SAPP = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,:,'Nuclear_pp',:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### BENI REGION - BENR ###

ICE_pp_BENR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'BENR',['ICE_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toLPZR_BENR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'BENR',['AC_transmission_115:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromLPZR_BENR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'BENR',['AC_transmission_115:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### LA PAZ REGION - LPZR ###

OCGT_pp_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
ICE_pp_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['ICE_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Bio_pp_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['Bio_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Large_hydro_pp_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['Large_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Small_hydro_pp_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['Small_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()


INTNTL_fromBENR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_115:BENR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toORUR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_230:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCOCR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toBENR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_115:BENR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromORUR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_230:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromCOCR_LPZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'LPZR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### COCHABAMBA REGION - COCR ###

OCGT_pp_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
CCGT_pp_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['CCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Wind_pp_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['Wind_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Large_hydro_pp_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['Large_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Small_hydro_pp_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['Large_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromLPZR_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toORUR_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_115:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toPOTR_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_115:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCHUR_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:CHUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toSCZR_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:SCZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toLPZR_COCR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromORUR_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_115:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromPOTR_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_115:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromCHUR_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:CHUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromSCZR_COCR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'COCR',['AC_transmission_230:SCZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### SANTA CRUZ REGION - SCZR ###

OCGT_pp_SCZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
CCGT_pp_SCZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['CCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Bio_pp_SCZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['Bio_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Nuclear_pp_SCZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['Nuclear_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromCOCR_SCZR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCOCR_SCZR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'SCZR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### ORURO REGION - ORUR ###

Solar_pp_oruro_ORUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['Solar_pp_oruro'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromLPZR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_230:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromCOCR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_115:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromPOTR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_115:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toLPZR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_230:LPZR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCOCR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_115:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toPOTR_ORUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'ORUR',['AC_transmission_115:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### POTOSI' REGION - POTR ###

OCGT_pp_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Large_hydro_pp_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['Large_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Small_hydro_pp_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['Small_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Solar_pp_uyuni_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['Solar_pp_uyuni'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromCOCR_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_115:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toORUR_POTR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_115:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCHUR_POTR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_69:CHUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toTAJR_POTR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_230:TAJR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCOCR_POTR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_115:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromORUR_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_115:ORUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromCHUR_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_69:CHUR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromTAJR_POTR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'POTR',['AC_transmission_230:TAJR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### CHUQUISACA REGION - CHUR ###

OCGT_pp_CHUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Dual_Fuel_pp_CHUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['Dual_Fuel_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromCOCR_CHUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_fromPOTR_CHUR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['AC_transmission_69:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toCOCR_CHUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['AC_transmission_230:COCR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toPOTR_CHUR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'CHUR',['AC_transmission_69:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

### TARIJA REGION - TAJR ###

OCGT_pp_TAJR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['OCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
CCGT_pp_TAJR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['CCGT_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Small_hydro_pp_TAJR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['Small_hydro_pp'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
Solar_pp_yunchara_TAJR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['Solar_pp_yunchara'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

INTNTL_fromPOTR_TAJR = pd.read_csv('RisultatiAnno/results_carrier_prod.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['AC_transmission_230:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()
INTNTL_toPOTR_TAJR = pd.read_csv('RisultatiAnno/results_carrier_con.csv', index_col=[0,1,2,3]).loc[idx[:,'TAJR',['AC_transmission_230:POTR'],:],:].groupby(level=['timesteps'],axis=0,sort=False).sum()

#%% INDEX DATETIME

demand_SAPP.index = pd.to_datetime(demand_SAPP.index)
demand_BENR.index = pd.to_datetime(demand_BENR.index)
demand_LPZR.index = pd.to_datetime(demand_LPZR.index)
demand_COCR.index = pd.to_datetime(demand_COCR.index)
demand_ORUR.index = pd.to_datetime(demand_ORUR.index)
demand_POTR.index = pd.to_datetime(demand_POTR.index)
demand_CHUR.index = pd.to_datetime(demand_CHUR.index)
demand_TAJR.index = pd.to_datetime(demand_TAJR.index)
demand_SCZR.index = pd.to_datetime(demand_SCZR.index)

OCGT_pp_SAPP.index = pd.to_datetime(OCGT_pp_SAPP.index)
CCGT_pp_SAPP.index = pd.to_datetime(CCGT_pp_SAPP.index)
Dual_Fuel_pp_SAPP.index = pd.to_datetime(Dual_Fuel_pp_SAPP.index)
ICE_pp_SAPP.index = pd.to_datetime(ICE_pp_SAPP.index)
Bio_pp_SAPP.index = pd.to_datetime(Bio_pp_SAPP.index)
Small_hydro_pp_SAPP.index = pd.to_datetime(Small_hydro_pp_SAPP.index)
Large_hydro_pp_SAPP.index = pd.to_datetime(Large_hydro_pp_SAPP.index)
Wind_pp_SAPP.index = pd.to_datetime(Wind_pp_SAPP.index)
Solar_pp_oruro_SAPP.index = pd.to_datetime(Solar_pp_oruro_SAPP.index)
Solar_pp_yunchara_SAPP.index = pd.to_datetime(Solar_pp_yunchara_SAPP.index)
Solar_pp_uyuni_SAPP.index = pd.to_datetime(Solar_pp_uyuni_SAPP.index)
Nuclear_pp_SAPP.index = pd.to_datetime(Nuclear_pp_SAPP.index)

ICE_pp_BENR.index = pd.to_datetime(ICE_pp_BENR.index)
INTNTL_toLPZR_BENR.index = pd.to_datetime(INTNTL_toLPZR_BENR.index)
INTNTL_fromLPZR_BENR.index = pd.to_datetime(INTNTL_fromLPZR_BENR.index)

OCGT_pp_LPZR.index = pd.to_datetime(OCGT_pp_LPZR.index)
ICE_pp_LPZR.index = pd.to_datetime(ICE_pp_LPZR.index)
Bio_pp_LPZR.index = pd.to_datetime(Bio_pp_LPZR.index)
Large_hydro_pp_LPZR.index = pd.to_datetime(Large_hydro_pp_LPZR.index)
Small_hydro_pp_LPZR.index = pd.to_datetime(Small_hydro_pp_LPZR.index)
INTNTL_fromBENR_LPZR.index = pd.to_datetime(INTNTL_fromBENR_LPZR.index)
INTNTL_toORUR_LPZR.index = pd.to_datetime(INTNTL_toORUR_LPZR.index)
INTNTL_toCOCR_LPZR.index = pd.to_datetime(INTNTL_toCOCR_LPZR.index)
INTNTL_toBENR_LPZR.index = pd.to_datetime(INTNTL_toBENR_LPZR.index)
INTNTL_fromORUR_LPZR.index = pd.to_datetime(INTNTL_fromORUR_LPZR.index)
INTNTL_fromCOCR_LPZR.index = pd.to_datetime(INTNTL_fromCOCR_LPZR.index)

OCGT_pp_COCR.index = pd.to_datetime(OCGT_pp_COCR.index)
CCGT_pp_COCR.index = pd.to_datetime(CCGT_pp_COCR.index)
Wind_pp_COCR.index = pd.to_datetime(Wind_pp_COCR.index)
Large_hydro_pp_COCR.index = pd.to_datetime(Large_hydro_pp_COCR.index)
Small_hydro_pp_COCR.index = pd.to_datetime(Small_hydro_pp_COCR.index)
INTNTL_fromLPZR_COCR.index = pd.to_datetime(INTNTL_fromLPZR_COCR.index)
INTNTL_toORUR_COCR.index = pd.to_datetime(INTNTL_toORUR_COCR.index)
INTNTL_toPOTR_COCR.index = pd.to_datetime(INTNTL_toPOTR_COCR.index)
INTNTL_toCHUR_COCR.index = pd.to_datetime(INTNTL_toCHUR_COCR.index)
INTNTL_toSCZR_COCR.index = pd.to_datetime(INTNTL_toSCZR_COCR.index)
INTNTL_toLPZR_COCR.index = pd.to_datetime(INTNTL_toLPZR_COCR.index)
INTNTL_fromORUR_COCR.index = pd.to_datetime(INTNTL_fromORUR_COCR.index)
INTNTL_fromPOTR_COCR.index = pd.to_datetime(INTNTL_fromPOTR_COCR.index)
INTNTL_fromCHUR_COCR.index = pd.to_datetime(INTNTL_fromCHUR_COCR.index)
INTNTL_fromSCZR_COCR.index = pd.to_datetime(INTNTL_fromSCZR_COCR.index)

OCGT_pp_SCZR.index = pd.to_datetime(OCGT_pp_SCZR.index)
CCGT_pp_SCZR.index = pd.to_datetime(CCGT_pp_SCZR.index)
Bio_pp_SCZR.index = pd.to_datetime(Bio_pp_SCZR.index)
Nuclear_pp_SCZR.index = pd.to_datetime(Nuclear_pp_SCZR.index)
INTNTL_fromCOCR_SCZR.index = pd.to_datetime(INTNTL_fromCOCR_SCZR.index)
INTNTL_toCOCR_SCZR.index = pd.to_datetime(INTNTL_toCOCR_SCZR.index)

Solar_pp_oruro_ORUR.index = pd.to_datetime(Solar_pp_oruro_ORUR.index)
INTNTL_fromLPZR_ORUR.index = pd.to_datetime(INTNTL_fromLPZR_ORUR.index)
INTNTL_fromCOCR_ORUR.index = pd.to_datetime(INTNTL_fromCOCR_ORUR.index)
INTNTL_fromPOTR_ORUR.index = pd.to_datetime(INTNTL_fromPOTR_ORUR.index)
INTNTL_toLPZR_ORUR.index = pd.to_datetime(INTNTL_toLPZR_ORUR.index)
INTNTL_toCOCR_ORUR.index = pd.to_datetime(INTNTL_toCOCR_ORUR.index)
INTNTL_toPOTR_ORUR.index = pd.to_datetime(INTNTL_toPOTR_ORUR.index)


OCGT_pp_POTR.index = pd.to_datetime(OCGT_pp_POTR.index)
Large_hydro_pp_POTR.index = pd.to_datetime(Large_hydro_pp_POTR.index)
Small_hydro_pp_POTR.index = pd.to_datetime(Small_hydro_pp_POTR.index)
Solar_pp_uyuni_POTR.index = pd.to_datetime(Solar_pp_uyuni_POTR.index)
INTNTL_fromCOCR_POTR.index = pd.to_datetime(INTNTL_fromCOCR_POTR.index)
INTNTL_toORUR_POTR.index = pd.to_datetime(INTNTL_toORUR_POTR.index)
INTNTL_toCHUR_POTR.index = pd.to_datetime(INTNTL_toCHUR_POTR.index)
INTNTL_toTAJR_POTR.index = pd.to_datetime(INTNTL_toTAJR_POTR.index)
INTNTL_toCOCR_POTR.index = pd.to_datetime(INTNTL_toCOCR_POTR.index)
INTNTL_fromORUR_POTR.index = pd.to_datetime(INTNTL_fromORUR_POTR.index)
INTNTL_fromCHUR_POTR.index = pd.to_datetime(INTNTL_fromCHUR_POTR.index)
INTNTL_fromTAJR_POTR.index = pd.to_datetime(INTNTL_fromTAJR_POTR.index)

OCGT_pp_CHUR.index = pd.to_datetime(OCGT_pp_CHUR.index)
Dual_Fuel_pp_CHUR.index = pd.to_datetime(Dual_Fuel_pp_CHUR.index)
INTNTL_fromCOCR_CHUR.index = pd.to_datetime(INTNTL_fromCOCR_CHUR.index)
INTNTL_fromPOTR_CHUR.index = pd.to_datetime(INTNTL_fromPOTR_CHUR.index)
INTNTL_toCOCR_CHUR.index = pd.to_datetime(INTNTL_toCOCR_CHUR.index)
INTNTL_toPOTR_CHUR.index = pd.to_datetime(INTNTL_toPOTR_CHUR.index)


OCGT_pp_TAJR.index = pd.to_datetime(OCGT_pp_TAJR.index)
CCGT_pp_TAJR.index= pd.to_datetime(CCGT_pp_TAJR.index)
Small_hydro_pp_TAJR.index = pd.to_datetime(Small_hydro_pp_TAJR.index)
Solar_pp_yunchara_TAJR.index = pd.to_datetime(Solar_pp_yunchara_TAJR.index)
INTNTL_fromPOTR_TAJR.index = pd.to_datetime(INTNTL_fromPOTR_TAJR.index)
INTNTL_toPOTR_TAJR.index = pd.to_datetime(INTNTL_toPOTR_TAJR.index)

#%% RESAMPLING

demand_SAPP = demand_SAPP.resample('W').mean()
demand_BENR = demand_BENR.resample('W').mean()
demand_LPZR = demand_LPZR.resample('W').mean()
demand_COCR = demand_COCR.resample('W').mean()
demand_ORUR = demand_ORUR.resample('W').mean()
demand_POTR = demand_POTR.resample('W').mean()
demand_CHUR = demand_CHUR.resample('W').mean()
demand_TAJR = demand_TAJR.resample('W').mean()
demand_SCZR= demand_SCZR.resample('W').mean()

OCGT_pp_SAPP = OCGT_pp_SAPP.resample('W').mean()
CCGT_pp_SAPP = CCGT_pp_SAPP.resample('W').mean()
Dual_Fuel_pp_SAPP = Dual_Fuel_pp_SAPP.resample('W').mean()
ICE_pp_SAPP = ICE_pp_SAPP.resample('W').mean()
Bio_pp_SAPP = Bio_pp_SAPP.resample('W').mean()
Small_hydro_pp_SAPP = Small_hydro_pp_SAPP.resample('W').mean()
Large_hydro_pp_SAPP = Large_hydro_pp_SAPP.resample('W').mean()
Wind_pp_SAPP = Wind_pp_SAPP.resample('W').mean()
Solar_pp_oruro_SAPP = Solar_pp_oruro_SAPP.resample('W').mean()
Solar_pp_yunchara_SAPP = Solar_pp_yunchara_SAPP.resample('W').mean()
Solar_pp_uyuni_SAPP = Solar_pp_uyuni_SAPP.resample('W').mean()
Nuclear_pp_SAPP = Nuclear_pp_SAPP.resample('W').mean()

ICE_pp_BENR = ICE_pp_BENR.resample('W').mean()
INTNTL_toLPZR_BENR = INTNTL_toLPZR_BENR.resample('W').mean()
INTNTL_fromLPZR_BENR = INTNTL_fromLPZR_BENR.resample('W').mean()

OCGT_pp_LPZR = OCGT_pp_LPZR.resample('W').mean()
ICE_pp_LPZR = ICE_pp_LPZR.resample('W').mean()
Bio_pp_LPZR = Bio_pp_LPZR.resample('W').mean()
Large_hydro_pp_LPZR = Large_hydro_pp_LPZR.resample('W').mean()
Small_hydro_pp_LPZR = Small_hydro_pp_LPZR.resample('W').mean()
INTNTL_fromBENR_LPZR = INTNTL_fromBENR_LPZR.resample('W').mean()
INTNTL_toORUR_LPZR = INTNTL_toORUR_LPZR.resample('W').mean()
INTNTL_toCOCR_LPZR = INTNTL_toCOCR_LPZR.resample('W').mean()
INTNTL_toBENR_LPZR = INTNTL_toBENR_LPZR.resample('W').mean()
INTNTL_fromORUR_LPZR = INTNTL_fromORUR_LPZR.resample('W').mean()
INTNTL_fromCOCR_LPZR = INTNTL_fromCOCR_LPZR.resample('W').mean()

OCGT_pp_COCR = OCGT_pp_COCR.resample('W').mean()
CCGT_pp_COCR = CCGT_pp_COCR.resample('W').mean()
Wind_pp_COCR = Wind_pp_COCR.resample('W').mean()
Large_hydro_pp_COCR = Large_hydro_pp_COCR.resample('W').mean()
Small_hydro_pp_COCR = Small_hydro_pp_COCR.resample('W').mean()
INTNTL_fromLPZR_COCR = INTNTL_fromLPZR_COCR.resample('W').mean()
INTNTL_toORUR_COCR = INTNTL_toORUR_COCR.resample('W').mean()
INTNTL_toPOTR_COCR = INTNTL_toPOTR_COCR.resample('W').mean()
INTNTL_toCHUR_COCR = INTNTL_toCHUR_COCR.resample('W').mean()
INTNTL_toSCZR_COCR = INTNTL_toSCZR_COCR.resample('W').mean()
INTNTL_toLPZR_COCR = INTNTL_toLPZR_COCR.resample('W').mean()
INTNTL_fromORUR_COCR = INTNTL_fromORUR_COCR.resample('W').mean()
INTNTL_fromPOTR_COCR = INTNTL_fromPOTR_COCR.resample('W').mean()
INTNTL_fromCHUR_COCR = INTNTL_fromCHUR_COCR.resample('W').mean()
INTNTL_fromSCZR_COCR = INTNTL_fromSCZR_COCR.resample('W').mean()

OCGT_pp_SCZR = OCGT_pp_SCZR.resample('W').mean()
CCGT_pp_SCZR = CCGT_pp_SCZR.resample('W').mean()
Bio_pp_SCZR = Bio_pp_SCZR.resample('W').mean()
Nuclear_pp_SCZR = Nuclear_pp_SCZR.resample('W').mean()
INTNTL_fromCOCR_SCZR = INTNTL_fromCOCR_SCZR.resample('W').mean()
INTNTL_toCOCR_SCZR = INTNTL_toCOCR_SCZR.resample('W').mean()

Solar_pp_oruro_ORUR = Solar_pp_oruro_ORUR.resample('W').mean()
INTNTL_fromLPZR_ORUR = INTNTL_fromLPZR_ORUR.resample('W').mean()
INTNTL_fromCOCR_ORUR = INTNTL_fromCOCR_ORUR.resample('W').mean()
INTNTL_fromPOTR_ORUR = INTNTL_fromPOTR_ORUR.resample('W').mean()
INTNTL_toLPZR_ORUR = INTNTL_toLPZR_ORUR.resample('W').mean()
INTNTL_toCOCR_ORUR = INTNTL_toCOCR_ORUR.resample('W').mean()
INTNTL_toPOTR_ORUR = INTNTL_toPOTR_ORUR.resample('W').mean()

OCGT_pp_POTR = OCGT_pp_POTR.resample('W').mean()
Large_hydro_pp_POTR = Large_hydro_pp_POTR.resample('W').mean()
Small_hydro_pp_POTR = Small_hydro_pp_POTR.resample('W').mean()
Solar_pp_uyuni_POTR = Solar_pp_uyuni_POTR.resample('W').mean()
INTNTL_fromCOCR_POTR = INTNTL_fromCOCR_POTR.resample('W').mean()
INTNTL_toORUR_POTR = INTNTL_toORUR_POTR.resample('W').mean()
INTNTL_toCHUR_POTR = INTNTL_toCHUR_POTR.resample('W').mean()
INTNTL_toTAJR_POTR = INTNTL_toTAJR_POTR.resample('W').mean()
INTNTL_toCOCR_POTR = INTNTL_toCOCR_POTR.resample('W').mean()
INTNTL_fromORUR_POTR = INTNTL_fromORUR_POTR.resample('W').mean()
INTNTL_fromCHUR_POTR = INTNTL_fromCHUR_POTR.resample('W').mean()
INTNTL_fromTAJR_POTR = INTNTL_fromTAJR_POTR.resample('W').mean()

OCGT_pp_CHUR = OCGT_pp_CHUR.resample('W').mean()
Dual_Fuel_pp_CHUR = Dual_Fuel_pp_CHUR.resample('W').mean()
INTNTL_fromCOCR_CHUR = INTNTL_fromCOCR_CHUR.resample('W').mean()
INTNTL_fromPOTR_CHUR = INTNTL_fromPOTR_CHUR.resample('W').mean()
INTNTL_toCOCR_CHUR = INTNTL_toCOCR_CHUR.resample('W').mean()
INTNTL_toPOTR_CHUR = INTNTL_toPOTR_CHUR.resample('W').mean()


OCGT_pp_TAJR = OCGT_pp_TAJR.resample('W').mean()
CCGT_pp_TAJR = CCGT_pp_TAJR.resample('W').mean()
Small_hydro_pp_TAJR = Small_hydro_pp_TAJR.resample('W').mean()
Solar_pp_yunchara_TAJR = Solar_pp_yunchara_TAJR.resample('W').mean()
INTNTL_fromPOTR_TAJR = INTNTL_fromPOTR_TAJR.resample('W').mean()
INTNTL_toPOTR_TAJR = INTNTL_toPOTR_TAJR.resample('W').mean()

#%% ## PREPROCESSING ## 

day = '2021-01-01 00:00:00'
end = '2021-12-31 23:00:00'

#%%  ### PLOTTING SAPP ###

Nuclear_pp_SAPP_cum = Nuclear_pp_SAPP/1000000
Large_hydro_pp_SAPP_cum = Nuclear_pp_SAPP_cum + Large_hydro_pp_SAPP/1000000
Small_hydro_pp_SAPP_cum = Large_hydro_pp_SAPP_cum + Small_hydro_pp_SAPP/1000000
ICE_pp_SAPP_cum = Small_hydro_pp_SAPP_cum + ICE_pp_SAPP/1000000
Bio_pp_SAPP_cum = ICE_pp_SAPP_cum + Bio_pp_SAPP/1000000
Dual_Fuel_pp_SAPP_cum = Bio_pp_SAPP_cum + Dual_Fuel_pp_SAPP/1000000
OCGT_pp_SAPP_cum = Dual_Fuel_pp_SAPP_cum + OCGT_pp_SAPP/1000000
CCGT_pp_SAPP_cum = OCGT_pp_SAPP_cum + CCGT_pp_SAPP/1000000
Wind_pp_SAPP_cum = CCGT_pp_SAPP_cum + Wind_pp_SAPP/1000000
Solar_pp_oruro_SAPP_cum = Wind_pp_SAPP_cum + Solar_pp_oruro_SAPP/1000000
Solar_pp_uyuni_SAPP_cum = Solar_pp_oruro_SAPP_cum + Solar_pp_uyuni_SAPP/1000000
Solar_pp_yunchara_SAPP_cum = Solar_pp_uyuni_SAPP_cum + Solar_pp_yunchara_SAPP/1000000

Nuclear_pp_SAPP_cum_SRS = Nuclear_pp_SAPP_cum.squeeze()
Large_hydro_pp_SAPP_cum_SRS = Large_hydro_pp_SAPP_cum.squeeze()
Small_hydro_pp_SAPP_cum_SRS = Small_hydro_pp_SAPP_cum.squeeze()
ICE_pp_SAPP_cum_SRS = ICE_pp_SAPP_cum.squeeze()
Bio_pp_SAPP_cum_SRS = Bio_pp_SAPP_cum.squeeze()
Dual_Fuel_pp_SAPP_cum_SRS = Dual_Fuel_pp_SAPP_cum.squeeze()
OCGT_pp_SAPP_cum_SRS = OCGT_pp_SAPP_cum.squeeze()
CCGT_pp_SAPP_cum_SRS = CCGT_pp_SAPP_cum.squeeze()
Wind_pp_SAPP_cum_SRS = Wind_pp_SAPP_cum.squeeze()
Solar_pp_oruro_SAPP_cum_SRS = Solar_pp_oruro_SAPP_cum.squeeze()
Solar_pp_uyuni_SAPP_cum_SRS = Solar_pp_uyuni_SAPP_cum.squeeze()
Solar_pp_yunchara_SAPP_cum_SRS = Solar_pp_yunchara_SAPP_cum.squeeze()

fig, (ax) = plt.subplots(1, figsize=(12,8))

# positive side #
ax.plot(Nuclear_pp_SAPP_cum[day:end].index,Nuclear_pp_SAPP_cum[day:end].values,'#008000', alpha=0.2)
ax.plot(Large_hydro_pp_SAPP_cum[day:end].index,Large_hydro_pp_SAPP_cum[day:end].values,'#0000cd', alpha=0.2)
ax.plot(Small_hydro_pp_SAPP_cum[day:end].index,Small_hydro_pp_SAPP_cum[day:end].values,'#6495ed', alpha=0.2)
ax.plot(ICE_pp_SAPP_cum[day:end].index,ICE_pp_SAPP_cum[day:end].values,'#ee6aa7', alpha=0.2)
ax.plot(Bio_pp_SAPP_cum[day:end].index,Bio_pp_SAPP_cum[day:end].values,'#adff2f', alpha=0.2)
ax.plot(Dual_Fuel_pp_SAPP_cum[day:end].index,Dual_Fuel_pp_SAPP_cum[day:end].values,'#daa520', alpha=0.2)
ax.plot(OCGT_pp_SAPP_cum[day:end].index,OCGT_pp_SAPP_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax.plot(CCGT_pp_SAPP_cum[day:end].index,CCGT_pp_SAPP_cum[day:end].values,'#8c000f', alpha=0.2)
ax.plot(Wind_pp_SAPP_cum[day:end].index,Wind_pp_SAPP_cum[day:end].values,'#7fffd4', alpha=0.2)
ax.plot(Solar_pp_oruro_SAPP_cum[day:end].index,Solar_pp_oruro_SAPP_cum[day:end].values,'#ffd700', alpha=0.2)
ax.plot(Solar_pp_uyuni_SAPP_cum[day:end].index,Solar_pp_uyuni_SAPP_cum[day:end].values,'#ffd700', alpha=0.2)
ax.plot(Solar_pp_yunchara_SAPP_cum[day:end].index,Solar_pp_yunchara_SAPP_cum[day:end].values,'#ffd700', alpha=0.2)

ax.set_ylabel('Power (GW)',labelpad = 11)

ax.margins(x=0)
ax.margins(y=0)

# Fill #

ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,0,Nuclear_pp_SAPP_cum_SRS[day:end].values,facecolor = '#008000', alpha = 0.6, label = 'Nuclear')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Nuclear_pp_SAPP_cum_SRS[day:end].values,Large_hydro_pp_SAPP_cum_SRS[day:end].values,facecolor = '#0000cd', alpha = 0.6, label = 'Large Hydro')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Large_hydro_pp_SAPP_cum_SRS[day:end].values,Small_hydro_pp_SAPP_cum_SRS[day:end].values,facecolor = '#6495ed', alpha = 0.6, label = 'Small Hydro')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Small_hydro_pp_SAPP_cum_SRS[day:end].values,ICE_pp_SAPP_cum_SRS[day:end].values,facecolor = '#ee6aa7', alpha = 0.6, label = 'ICE')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,ICE_pp_SAPP_cum_SRS[day:end].values,Bio_pp_SAPP_cum_SRS[day:end].values,facecolor = '#adff2f', alpha = 0.6, label = 'Biomass')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Bio_pp_SAPP_cum_SRS[day:end].values,Dual_Fuel_pp_SAPP_cum_SRS[day:end].values,facecolor = '#daa520', alpha = 0.6, label = 'Dual Fuel')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Dual_Fuel_pp_SAPP_cum_SRS[day:end].values,OCGT_pp_SAPP_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,OCGT_pp_SAPP_cum_SRS[day:end].values,CCGT_pp_SAPP_cum_SRS[day:end].values,facecolor = '#8c000f', alpha = 0.6, label = 'CCGT')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,CCGT_pp_SAPP_cum_SRS[day:end].values,Wind_pp_SAPP_cum_SRS[day:end].values,facecolor = '#7fffd4', alpha = 0.6, label = 'Wind')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Wind_pp_SAPP_cum_SRS[day:end].values,Solar_pp_oruro_SAPP_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar Oruro')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Solar_pp_oruro_SAPP_cum_SRS[day:end].values,Solar_pp_uyuni_SAPP_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar Uyuni')
ax.fill_between(Nuclear_pp_SAPP_cum_SRS[day:end].index,Solar_pp_uyuni_SAPP_cum_SRS[day:end].values,Solar_pp_yunchara_SAPP_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar Yunchara')

lgd1 = ax.legend(loc=1,  bbox_to_anchor=(1.2, 1))

ax.set_title('Bolivian Power', size = 20)

#%% NATIONAL 
fig, ((ax1, ax2), (ax3, ax4), (ax5,ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(24,30), sharex=False, sharey=False)
fig.suptitle('Dispatch Analysis Calliope')
plt.rc('figure', titlesize=30)

### DEMANDS ###

demand_BENR_cum = -demand_BENR/1000000
demand_LPZR_cum = -demand_LPZR/1000000
demand_COCR_cum = -demand_COCR/1000000
demand_ORUR_cum = -demand_ORUR/1000000
demand_POTR_cum = -demand_POTR/1000000
demand_CHUR_cum = -demand_CHUR/1000000
demand_TAJR_cum = -demand_TAJR/1000000
demand_SCZR_cum = -demand_SCZR/1000000

### BENI REGION - BENR ###

ICE_pp_BENR_cum = ICE_pp_BENR/1000000
INTNTL_fromLPZR_BENR_cum = ICE_pp_BENR_cum + INTNTL_fromLPZR_BENR/1000000
INTNTL_toLPZR_BENR_cum = INTNTL_toLPZR_BENR/1000000

ICE_pp_BENR_cum_SRS = ICE_pp_BENR_cum.squeeze()
INTNTL_toLPZR_BENR_cum_SRS = INTNTL_toLPZR_BENR_cum.squeeze()
INTNTL_fromLPZR_BENR_cum_SRS = INTNTL_fromLPZR_BENR_cum.squeeze()


# positive side #
ax1.plot(demand_BENR_cum[day:end].index,demand_BENR_cum[day:end].values,'#000000')
ax1.plot(ICE_pp_BENR_cum[day:end].index,ICE_pp_BENR_cum[day:end].values,'#ee6aa7', alpha=0.2)
ax1.plot(INTNTL_fromLPZR_BENR_cum[day:end].index,INTNTL_fromLPZR_BENR_cum[day:end].values,'#ffefdb', alpha=0.2)

# negative side #
ax1.plot(INTNTL_toLPZR_BENR_cum[day:end].index,INTNTL_toLPZR_BENR_cum[day:end].values,'#adff2f', alpha=0.2)

ax1.set_ylabel('Power (GW)',labelpad = 11)

ax1.margins(x=0)
ax1.margins(y=0)

# Fill #

ax1.fill_between(ICE_pp_BENR_cum[day:end].index,0,ICE_pp_BENR_cum_SRS[day:end].values,facecolor = '#ee6aa7', alpha = 0.6, label = 'ICE')
ax1.fill_between(ICE_pp_BENR_cum_SRS[day:end].index,ICE_pp_BENR_cum_SRS[day:end].values,INTNTL_fromLPZR_BENR_cum_SRS[day:end].values,facecolor = '#ffefdb', alpha = 0.6, label = 'Import from LPZR')
ax1.fill_between(ICE_pp_BENR_cum_SRS[day:end].index,0,INTNTL_toLPZR_BENR_cum_SRS[day:end].values,facecolor = '#adff2f', alpha = 0.6, label = 'Export to LPZR')

ax1.set_title('BENR', size = 20)


### LA PAZ REGION - LPZR ###

Large_hydro_pp_LPZR_cum = Large_hydro_pp_LPZR/1000000
Small_hydro_pp_LPZR_cum = Large_hydro_pp_LPZR_cum + Small_hydro_pp_LPZR/1000000
OCGT_pp_LPZR_cum = Small_hydro_pp_LPZR_cum + OCGT_pp_LPZR/1000000
ICE_pp_LPZR_cum = OCGT_pp_LPZR_cum + ICE_pp_LPZR/1000000
Bio_pp_LPZR_cum = ICE_pp_LPZR_cum + Bio_pp_LPZR/1000000
INTNTL_fromBENR_LPZR_cum = Bio_pp_LPZR_cum + INTNTL_fromBENR_LPZR/1000000
INTNTL_fromORUR_LPZR_cum = INTNTL_fromBENR_LPZR_cum + INTNTL_fromORUR_LPZR/1000000
INTNTL_fromCOCR_LPZR_cum = INTNTL_fromORUR_LPZR_cum + INTNTL_fromCOCR_LPZR/1000000

INTNTL_toBENR_LPZR_cum = INTNTL_toBENR_LPZR/1000000
INTNTL_toORUR_LPZR_cum = INTNTL_toBENR_LPZR_cum + INTNTL_toORUR_LPZR/1000000
INTNTL_toCOCR_LPZR_cum = INTNTL_toORUR_LPZR_cum + INTNTL_toCOCR_LPZR/1000000

OCGT_pp_LPZR_cum_SRS = OCGT_pp_LPZR_cum.squeeze()
ICE_pp_LPZR_cum_SRS = ICE_pp_LPZR_cum.squeeze()
Bio_pp_LPZR_cum_SRS = Bio_pp_LPZR_cum.squeeze()
Large_hydro_pp_LPZR_cum_SRS = Large_hydro_pp_LPZR_cum.squeeze()
Small_hydro_pp_LPZR_cum_SRS = Small_hydro_pp_LPZR_cum.squeeze()
INTNTL_fromBENR_LPZR_cum_SRS = INTNTL_fromBENR_LPZR_cum.squeeze()
INTNTL_fromORUR_LPZR_cum_SRS = INTNTL_fromORUR_LPZR_cum.squeeze()
INTNTL_fromCOCR_LPZR_cum_SRS = INTNTL_fromCOCR_LPZR_cum.squeeze()

INTNTL_toBENR_LPZR_cum_SRS = INTNTL_toBENR_LPZR_cum.squeeze()
INTNTL_toORUR_LPZR_cum_SRS = INTNTL_toORUR_LPZR_cum.squeeze()
INTNTL_toCOCR_LPZR_cum_SRS = INTNTL_toCOCR_LPZR_cum.squeeze()

# positive side #
ax2.plot(demand_LPZR_cum[day:end].index,demand_LPZR_cum[day:end].values,'#000000')
ax2.plot(OCGT_pp_LPZR_cum[day:end].index,OCGT_pp_LPZR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax2.plot(ICE_pp_LPZR_cum[day:end].index,ICE_pp_LPZR_cum[day:end].values,'#ee6aa7', alpha=0.2)
ax2.plot(Bio_pp_LPZR_cum[day:end].index,Bio_pp_LPZR_cum[day:end].values,'#adff2f', alpha=0.2)
ax2.plot(Large_hydro_pp_LPZR_cum[day:end].index,Large_hydro_pp_LPZR_cum[day:end].values,'#0000cd', alpha=0.2)
ax2.plot(Small_hydro_pp_LPZR_cum[day:end].index,Small_hydro_pp_LPZR_cum[day:end].values,'#6495ed', alpha=0.2)
ax2.plot(INTNTL_fromBENR_LPZR_cum[day:end].index,INTNTL_fromBENR_LPZR_cum[day:end].values,'#ffefdb', alpha=0.2)
ax2.plot(INTNTL_fromORUR_LPZR_cum_SRS[day:end].index,INTNTL_fromORUR_LPZR_cum_SRS[day:end].values,'#fff0f5', alpha=0.2)
ax2.plot(INTNTL_fromCOCR_LPZR_cum_SRS[day:end].index,INTNTL_fromCOCR_LPZR_cum_SRS[day:end].values,'#e0ffff', alpha=0.2)

# negative side #
ax2.plot(INTNTL_toBENR_LPZR_cum_SRS[day:end].index,INTNTL_toBENR_LPZR_cum_SRS[day:end].values,'#9370db', alpha=0.2)
ax2.plot(INTNTL_toORUR_LPZR_cum[day:end].index,INTNTL_toORUR_LPZR_cum[day:end].values,'#ff69b4', alpha=0.2)
ax2.plot(INTNTL_toCOCR_LPZR_cum[day:end].index,INTNTL_toCOCR_LPZR_cum[day:end].values,'#00fa9a', alpha=0.2)

ax2.set_ylabel('Power (GW)',labelpad = 11)

ax2.margins(x=0)
ax2.margins(y=0)

# Fill #

ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,0,Large_hydro_pp_LPZR_cum_SRS[day:end].values,facecolor = '#0000cd', alpha = 0.6, label = 'Large Hydro')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,Large_hydro_pp_LPZR_cum_SRS[day:end].values,Small_hydro_pp_LPZR_cum_SRS[day:end].values,facecolor = '#6495ed', alpha = 0.6, label = 'Small Hydro')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,Small_hydro_pp_LPZR_cum_SRS[day:end].values,OCGT_pp_LPZR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,OCGT_pp_LPZR_cum_SRS[day:end].values,ICE_pp_LPZR_cum_SRS[day:end].values,facecolor = '#ee6aa7', alpha = 0.6, label = 'ICE')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,ICE_pp_LPZR_cum_SRS[day:end].values,Bio_pp_LPZR_cum_SRS[day:end].values,facecolor = '#adff2f', alpha = 0.6, label = 'Biomass')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,Bio_pp_LPZR_cum_SRS[day:end].values,INTNTL_fromBENR_LPZR_cum_SRS[day:end].values,facecolor = '#e6e6fa', alpha = 0.6, label = 'Import from BENR')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,INTNTL_fromBENR_LPZR_cum_SRS[day:end].values,INTNTL_fromORUR_LPZR_cum_SRS[day:end].values,facecolor = '#fff0f5', alpha = 0.6, label = 'Import from ORUR')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,INTNTL_fromORUR_LPZR_cum_SRS[day:end].values,INTNTL_fromCOCR_LPZR_cum_SRS[day:end].values,facecolor = '#e0ffff', alpha = 0.6, label = 'Import from COCR')

ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,0,INTNTL_toBENR_LPZR_cum_SRS[day:end].values,facecolor = '#9370db', alpha = 0.6, label = 'Export to BENR')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,INTNTL_toBENR_LPZR_cum_SRS[day:end].values,INTNTL_toORUR_LPZR_cum_SRS[day:end].values,facecolor = '#ff69b4', alpha = 0.6, label = 'Export to ORUR')
ax2.fill_between(Large_hydro_pp_LPZR_cum[day:end].index,INTNTL_toORUR_LPZR_cum_SRS[day:end].values,INTNTL_toCOCR_LPZR_cum_SRS[day:end].values,facecolor = '#00fa9a', alpha = 0.6, label = 'Export to COCR')

ax2.set_title('LPZR', size = 20)

### COCHABAMBA REGION - COCR ###

Large_hydro_pp_COCR_cum = Large_hydro_pp_COCR/1000000
Small_hydro_pp_COCR_cum = Large_hydro_pp_COCR_cum + Small_hydro_pp_COCR/1000000
OCGT_pp_COCR_cum = Small_hydro_pp_COCR_cum + OCGT_pp_COCR/1000000
CCGT_pp_COCR_cum = OCGT_pp_COCR_cum + CCGT_pp_COCR/1000000
Wind_pp_COCR_cum = CCGT_pp_COCR_cum + Wind_pp_COCR/1000000
INTNTL_fromLPZR_COCR_cum = Wind_pp_COCR_cum + INTNTL_fromLPZR_COCR/1000000
INTNTL_fromORUR_COCR_cum = INTNTL_fromLPZR_COCR_cum + INTNTL_fromORUR_COCR/1000000
INTNTL_fromPOTR_COCR_cum = INTNTL_fromORUR_COCR_cum + INTNTL_fromPOTR_COCR/1000000
INTNTL_fromCHUR_COCR_cum = INTNTL_fromPOTR_COCR_cum + INTNTL_fromCHUR_COCR/1000000
INTNTL_fromSCZR_COCR_cum = INTNTL_fromCHUR_COCR_cum + INTNTL_fromSCZR_COCR/1000000


INTNTL_toORUR_COCR_cum = INTNTL_toORUR_COCR/1000000
INTNTL_toPOTR_COCR_cum = INTNTL_toORUR_COCR_cum + INTNTL_toPOTR_COCR/1000000
INTNTL_toCHUR_COCR_cum = INTNTL_toPOTR_COCR_cum + INTNTL_toCHUR_COCR/1000000
INTNTL_toSCZR_COCR_cum = INTNTL_toCHUR_COCR_cum + INTNTL_toSCZR_COCR/1000000
INTNTL_toLPZR_COCR_cum = INTNTL_toSCZR_COCR_cum + INTNTL_toLPZR_COCR/1000000

OCGT_pp_COCR_cum_SRS = OCGT_pp_COCR_cum.squeeze()
CCGT_pp_COCR_cum_SRS = CCGT_pp_COCR_cum.squeeze()
Wind_pp_COCR_cum_SRS = Wind_pp_COCR_cum.squeeze()
Large_hydro_pp_COCR_cum_SRS = Large_hydro_pp_COCR_cum.squeeze()
Small_hydro_pp_COCR_cum_SRS = Small_hydro_pp_COCR_cum.squeeze()
INTNTL_fromLPZR_COCR_cum_SRS = INTNTL_fromLPZR_COCR_cum.squeeze()
INTNTL_fromORUR_COCR_cum_SRS = INTNTL_fromORUR_COCR_cum.squeeze()
INTNTL_fromPOTR_COCR_cum_SRS = INTNTL_fromPOTR_COCR_cum.squeeze()
INTNTL_fromCHUR_COCR_cum_SRS = INTNTL_fromCHUR_COCR_cum.squeeze()
INTNTL_fromSCZR_COCR_cum_SRS = INTNTL_fromSCZR_COCR_cum.squeeze()

INTNTL_toLPZR_COCR_cum_SRS = INTNTL_toLPZR_COCR_cum.squeeze()
INTNTL_toORUR_COCR_cum_SRS = INTNTL_toORUR_COCR_cum.squeeze()
INTNTL_toPOTR_COCR_cum_SRS = INTNTL_toPOTR_COCR_cum.squeeze()
INTNTL_toCHUR_COCR_cum_SRS = INTNTL_toCHUR_COCR_cum.squeeze()
INTNTL_toSCZR_COCR_cum_SRS = INTNTL_toSCZR_COCR_cum.squeeze()

# positive side #
ax3.plot(demand_COCR_cum[day:end].index,demand_COCR_cum[day:end].values,'#000000')
ax3.plot(OCGT_pp_COCR_cum[day:end].index,OCGT_pp_COCR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax3.plot(CCGT_pp_COCR_cum[day:end].index,CCGT_pp_COCR_cum[day:end].values,'#8c000f', alpha=0.2)
ax3.plot(Wind_pp_COCR_cum[day:end].index,Wind_pp_COCR_cum[day:end].values,'#7fffd4', alpha=0.2)
ax3.plot(Large_hydro_pp_COCR_cum[day:end].index,Large_hydro_pp_COCR_cum[day:end].values,'#0000cd', alpha=0.2)
ax3.plot(Small_hydro_pp_COCR_cum[day:end].index,Small_hydro_pp_COCR_cum[day:end].values,'#6495ed', alpha=0.2)
ax3.plot(INTNTL_fromLPZR_COCR_cum[day:end].index,INTNTL_fromLPZR_COCR_cum[day:end].values,'#ffefdb', alpha=0.2)
ax3.plot(INTNTL_fromPOTR_COCR_cum[day:end].index,INTNTL_fromPOTR_COCR_cum[day:end].values,'#bdfcc9', alpha=0.2)
ax3.plot(INTNTL_fromCHUR_COCR_cum[day:end].index,INTNTL_fromCHUR_COCR_cum[day:end].values,'#ffaeb9', alpha=0.2)
ax3.plot(INTNTL_fromSCZR_COCR_cum[day:end].index,INTNTL_fromSCZR_COCR_cum[day:end].values,'#f5fffa', alpha=0.2)
ax3.plot(INTNTL_fromORUR_COCR_cum[day:end].index,INTNTL_fromORUR_COCR_cum[day:end].values,'#fff0f5', alpha=0.2)

# negative side #

ax3.plot(INTNTL_toORUR_COCR_cum[day:end].index,INTNTL_toORUR_COCR_cum[day:end].values,'#ff69b4', alpha=0.2)
ax3.plot(INTNTL_toPOTR_COCR_cum[day:end].index,INTNTL_toPOTR_COCR_cum[day:end].values,'#cd853f', alpha=0.2)
ax3.plot(INTNTL_toCHUR_COCR_cum[day:end].index,INTNTL_toCHUR_COCR_cum[day:end].values,'#98fb98', alpha=0.2)
ax3.plot(INTNTL_toSCZR_COCR_cum[day:end].index,INTNTL_toSCZR_COCR_cum[day:end].values,'#ee7942', alpha=0.2)
ax3.plot(INTNTL_toLPZR_COCR_cum[day:end].index,INTNTL_toLPZR_COCR_cum[day:end].values,'#adff2f', alpha=0.2)

ax3.set_ylabel('Power (GW)',labelpad = 11)

ax3.margins(x=0)
ax3.margins(y=0)

# Fill #

ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,0,Large_hydro_pp_COCR_cum_SRS[day:end].values,facecolor = '#0000cd', alpha = 0.6, label = 'Large Hydro')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,Large_hydro_pp_COCR_cum_SRS[day:end].values,Small_hydro_pp_COCR_cum_SRS[day:end].values,facecolor = '#6495ed', alpha = 0.6, label = 'Small Hydro')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,Small_hydro_pp_COCR_cum_SRS[day:end].values,OCGT_pp_COCR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,OCGT_pp_COCR_cum_SRS[day:end].values,CCGT_pp_COCR_cum_SRS[day:end].values,facecolor = '#8c000f', alpha = 0.6, label = 'CCGT')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,CCGT_pp_COCR_cum_SRS[day:end].values,Wind_pp_COCR_cum_SRS[day:end].values,facecolor = '#7fffd4', alpha = 0.6, label = 'Wind')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,Wind_pp_COCR_cum_SRS[day:end].values,INTNTL_fromLPZR_COCR_cum_SRS[day:end].values,facecolor = '#ffefdb', alpha = 0.6, label = 'Import from LPZR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_fromLPZR_COCR_cum_SRS[day:end].values,INTNTL_fromORUR_COCR_cum_SRS[day:end].values,facecolor = '#fff0f5', alpha = 0.6, label = 'Import from ORUR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_fromORUR_COCR_cum_SRS[day:end].values,INTNTL_fromPOTR_COCR_cum_SRS[day:end].values,facecolor = '#bdfcc9', alpha = 0.6, label = 'Import from POTR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_fromPOTR_COCR_cum_SRS[day:end].values,INTNTL_fromCHUR_COCR_cum_SRS[day:end].values,facecolor = '#ffaeb9', alpha = 0.6, label = 'Import from CHUR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_fromCHUR_COCR_cum_SRS[day:end].values,INTNTL_fromSCZR_COCR_cum_SRS[day:end].values,facecolor = '#ab82ff', alpha = 0.6, label = 'Import from SCZR')


ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,0,INTNTL_toORUR_COCR_cum_SRS[day:end].values,facecolor = '#ff69b4', alpha = 0.6, label = 'Export to ORUR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_toORUR_COCR_cum_SRS[day:end].values,INTNTL_toPOTR_COCR_cum_SRS[day:end].values,facecolor = '#cd853f', alpha = 0.6, label = 'Export to POTR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_toPOTR_COCR_cum_SRS[day:end].values,INTNTL_toCHUR_COCR_cum_SRS[day:end].values,facecolor = '#98fb98', alpha = 0.6, label = 'Export to CHUR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_toCHUR_COCR_cum_SRS[day:end].values,INTNTL_toSCZR_COCR_cum_SRS[day:end].values,facecolor = '#ee7942', alpha = 0.6, label = 'Export to SCZR')
ax3.fill_between(Large_hydro_pp_COCR_cum[day:end].index,INTNTL_toSCZR_COCR_cum_SRS[day:end].values,INTNTL_toLPZR_COCR_cum_SRS[day:end].values,facecolor = '#adff2f', alpha = 0.6, label = 'Export to LPZR')


ax3.set_title('COCR', size = 20)  

### SANTA CRUZ REGION - SCZR ###

Nuclear_pp_SCZR_cum = Nuclear_pp_SCZR/1000000
OCGT_pp_SCZR_cum = Nuclear_pp_SCZR_cum + OCGT_pp_SCZR/1000000
CCGT_pp_SCZR_cum = OCGT_pp_SCZR_cum + CCGT_pp_SCZR/1000000
Bio_pp_SCZR_cum = CCGT_pp_SCZR_cum + Bio_pp_SCZR/1000000
INTNTL_fromCOCR_SCZR_cum = Bio_pp_SCZR_cum + INTNTL_fromCOCR_SCZR/1000000

INTNTL_toCOCR_SCZR_cum = INTNTL_toCOCR_SCZR/1000000

OCGT_pp_SCZR_cum_SRS = OCGT_pp_SCZR_cum.squeeze()
CCGT_pp_SCZR_cum_SRS = CCGT_pp_SCZR_cum.squeeze()
Bio_pp_SCZR_cum_SRS = Bio_pp_SCZR_cum.squeeze()
Nuclear_pp_SCZR_cum_SRS = Nuclear_pp_SCZR_cum.squeeze()
INTNTL_fromCOCR_SCZR_cum_SRS = INTNTL_fromCOCR_SCZR_cum.squeeze()
INTNTL_toCOCR_SCZR_cum_SRS = INTNTL_toCOCR_SCZR_cum.squeeze()

# positive side #
ax4.plot(demand_SCZR_cum[day:end].index,demand_SCZR_cum[day:end].values,'#000000')
ax4.plot(OCGT_pp_SCZR_cum[day:end].index,OCGT_pp_SCZR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax4.plot(CCGT_pp_SCZR_cum[day:end].index,CCGT_pp_SCZR_cum[day:end].values,'#8c000f', alpha=0.2)
ax4.plot(Bio_pp_SCZR_cum[day:end].index,Bio_pp_SCZR_cum[day:end].values,'#adff2f', alpha=0.2)
ax4.plot(Nuclear_pp_SCZR_cum[day:end].index,Nuclear_pp_SCZR_cum[day:end].values,'#008000', alpha=0.2)
ax4.plot(INTNTL_fromCOCR_SCZR_cum[day:end].index,INTNTL_fromCOCR_SCZR_cum[day:end].values,'#e0ffff', alpha=0.2)
ax4.plot(INTNTL_toCOCR_SCZR_cum[day:end].index,INTNTL_toCOCR_SCZR_cum[day:end].values,'#00fa9a', alpha=0.2)

ax4.set_ylabel('Power (GW)',labelpad = 11)

ax4.margins(x=0)
ax4.margins(y=0)

# Fill #

ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,0,Nuclear_pp_SCZR_cum_SRS[day:end].values,facecolor = '#008000', alpha = 0.6, label = 'Nuclear')
ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,Nuclear_pp_SCZR_cum_SRS[day:end].values,OCGT_pp_SCZR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,OCGT_pp_SCZR_cum_SRS[day:end].values,CCGT_pp_SCZR_cum_SRS[day:end].values,facecolor = '#8c000f', alpha = 0.6, label = 'CCGT')
ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,CCGT_pp_SCZR_cum_SRS[day:end].values,Bio_pp_SCZR_cum_SRS[day:end].values,facecolor = '#adff2f', alpha = 0.6, label = 'Biomass')
ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,Bio_pp_SCZR_cum_SRS[day:end].values,INTNTL_fromCOCR_SCZR_cum_SRS[day:end].values,facecolor = '#e0ffff', alpha = 0.6, label = 'Import from COCR')

ax4.fill_between(Nuclear_pp_SCZR_cum[day:end].index,0,INTNTL_toCOCR_SCZR_cum_SRS[day:end].values,facecolor = '#00fa9a', alpha = 0.6, label = 'Export to COCR')

ax4.set_title('SCZR', size = 20)  

### ORURO REGION - ORUR ###

Solar_pp_oruro_ORUR_cum = Solar_pp_oruro_ORUR/1000000
INTNTL_fromLPZR_ORUR_cum = Solar_pp_oruro_ORUR_cum + INTNTL_fromLPZR_ORUR/1000000
INTNTL_fromCOCR_ORUR_cum = INTNTL_fromLPZR_ORUR_cum + INTNTL_fromCOCR_ORUR/1000000
INTNTL_fromPOTR_ORUR_cum = INTNTL_fromCOCR_ORUR_cum + INTNTL_fromPOTR_ORUR/1000000
INTNTL_toLPZR_ORUR_cum = INTNTL_toLPZR_ORUR/1000000
INTNTL_toCOCR_ORUR_cum = INTNTL_toLPZR_ORUR_cum + INTNTL_toCOCR_ORUR/1000000
INTNTL_toPOTR_ORUR_cum = INTNTL_toCOCR_ORUR_cum + INTNTL_toPOTR_ORUR/1000000

Solar_pp_oruro_ORUR_cum_SRS = Solar_pp_oruro_ORUR_cum.squeeze()
INTNTL_fromLPZR_ORUR_cum_SRS = INTNTL_fromLPZR_ORUR_cum.squeeze()
INTNTL_fromCOCR_ORUR_cum_SRS = INTNTL_fromCOCR_ORUR_cum.squeeze()
INTNTL_fromPOTR_ORUR_cum_SRS = INTNTL_fromPOTR_ORUR_cum.squeeze()
INTNTL_toLPZR_ORUR_cum_SRS = INTNTL_toLPZR_ORUR_cum.squeeze()
INTNTL_toCOCR_ORUR_cum_SRS = INTNTL_toCOCR_ORUR_cum.squeeze()
INTNTL_toPOTR_ORUR_cum_SRS = INTNTL_toPOTR_ORUR_cum.squeeze()

# positive side #
ax5.plot(demand_ORUR_cum[day:end].index,demand_ORUR_cum[day:end].values,'#000000')
ax5.plot(Solar_pp_oruro_ORUR_cum[day:end].index,Solar_pp_oruro_ORUR_cum[day:end].values,'#ffd700', alpha=0.2)
ax5.plot(INTNTL_fromLPZR_ORUR_cum[day:end].index,INTNTL_fromLPZR_ORUR_cum[day:end].values,'#ffefdb', alpha=0.2)
ax5.plot(INTNTL_fromCOCR_ORUR_cum[day:end].index,INTNTL_fromCOCR_ORUR_cum[day:end].values,'#e0ffff', alpha=0.2)
ax5.plot(INTNTL_fromPOTR_ORUR_cum[day:end].index,INTNTL_fromPOTR_ORUR_cum[day:end].values,'#bdfcc9', alpha=0.2)
ax5.plot(INTNTL_toLPZR_ORUR_cum[day:end].index,INTNTL_toLPZR_ORUR_cum[day:end].values,'#adff2f', alpha=0.2)
ax5.plot(INTNTL_toCOCR_ORUR_cum[day:end].index,INTNTL_toCOCR_ORUR_cum[day:end].values,'#00fa9a', alpha=0.2)
ax5.plot(INTNTL_toPOTR_ORUR_cum[day:end].index,INTNTL_toPOTR_ORUR_cum[day:end].values,'#cd853f', alpha=0.2)

ax5.set_ylabel('Power (GW)',labelpad = 11)

ax5.margins(x=0)
ax5.margins(y=0)

# Fill #

ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,0,Solar_pp_oruro_ORUR_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar - Oruro')
ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,Solar_pp_oruro_ORUR_cum_SRS[day:end].values,INTNTL_fromLPZR_ORUR_cum_SRS[day:end].values,facecolor = '#ffefdb', alpha = 0.6, label = 'Import from LPZR')
ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,INTNTL_fromLPZR_ORUR_cum_SRS[day:end].values,INTNTL_fromCOCR_ORUR_cum_SRS[day:end].values,facecolor = '#e0ffff', alpha = 0.6, label = 'Import from COCR')
ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,INTNTL_fromCOCR_ORUR_cum_SRS[day:end].values,INTNTL_fromPOTR_ORUR_cum_SRS[day:end].values,facecolor = '#bdfcc9', alpha = 0.6, label = 'Import from POTR')

ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,INTNTL_toLPZR_ORUR_cum_SRS[day:end].values,facecolor = '#cd853f', alpha = 0.6, label = 'Export to POTR')
ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,INTNTL_toLPZR_ORUR_cum_SRS[day:end].values,INTNTL_toCOCR_ORUR_cum_SRS[day:end].values,facecolor = '#00fa9a', alpha = 0.6, label = 'Export to COCR')
ax5.fill_between(Solar_pp_oruro_ORUR_cum[day:end].index,INTNTL_toCOCR_ORUR_cum_SRS[day:end].values,INTNTL_toPOTR_ORUR_cum_SRS[day:end].values,facecolor = '#cd853f', alpha = 0.6, label = 'Export to POTR')

ax5.set_title('ORUR', size = 20)  


### POTOSI' REGION - POTR ###

Large_hydro_pp_POTR_cum = Large_hydro_pp_POTR/1000000
Small_hydro_pp_POTR_cum = Large_hydro_pp_POTR_cum + Small_hydro_pp_POTR/1000000
OCGT_pp_POTR_cum = Small_hydro_pp_POTR_cum + OCGT_pp_POTR/1000000
Solar_pp_uyuni_POTR_cum = OCGT_pp_POTR_cum + Solar_pp_uyuni_POTR/1000000
INTNTL_fromCOCR_POTR_cum = Solar_pp_uyuni_POTR_cum + INTNTL_fromCOCR_POTR/1000000
INTNTL_fromORUR_POTR_cum = INTNTL_fromCOCR_POTR_cum + INTNTL_fromORUR_POTR/1000000
INTNTL_fromCHUR_POTR_cum = INTNTL_fromORUR_POTR_cum + INTNTL_fromCHUR_POTR/1000000
INTNTL_fromTAJR_POTR_cum = INTNTL_fromCHUR_POTR_cum + INTNTL_fromTAJR_POTR/1000000

INTNTL_toCOCR_POTR_cum = INTNTL_toCOCR_POTR/1000000
INTNTL_toORUR_POTR_cum = INTNTL_toCOCR_POTR_cum + INTNTL_toORUR_POTR/1000000
INTNTL_toCHUR_POTR_cum = INTNTL_toORUR_POTR_cum + INTNTL_toCHUR_POTR/1000000
INTNTL_toTAJR_POTR_cum = INTNTL_toCHUR_POTR_cum + INTNTL_toTAJR_POTR/1000000


OCGT_pp_POTR_cum_SRS = OCGT_pp_POTR_cum.squeeze()
Large_hydro_pp_POTR_cum_SRS = Large_hydro_pp_POTR_cum.squeeze()
Small_hydro_pp_POTR_cum_SRS = Small_hydro_pp_POTR_cum.squeeze()
Solar_pp_uyuni_POTR_cum_SRS = Solar_pp_uyuni_POTR_cum.squeeze()
INTNTL_fromCOCR_POTR_cum_SRS = INTNTL_fromCOCR_POTR_cum.squeeze()
INTNTL_fromORUR_POTR_cum_SRS = INTNTL_fromORUR_POTR_cum.squeeze()
INTNTL_fromCHUR_POTR_cum_SRS = INTNTL_fromCHUR_POTR_cum.squeeze()
INTNTL_fromTAJR_POTR_cum_SRS = INTNTL_fromTAJR_POTR_cum.squeeze()
INTNTL_toORUR_POTR_cum_SRS = INTNTL_toORUR_POTR_cum.squeeze()
INTNTL_toCHUR_POTR_cum_SRS = INTNTL_toCHUR_POTR_cum.squeeze()
INTNTL_toTAJR_POTR_cum_SRS = INTNTL_toTAJR_POTR_cum.squeeze()
INTNTL_toCOCR_POTR_cum_SRS = INTNTL_toCOCR_POTR_cum.squeeze()

# positive side #
ax6.plot(demand_POTR_cum[day:end].index,demand_POTR_cum[day:end].values,'#000000')
ax6.plot(OCGT_pp_POTR_cum[day:end].index,OCGT_pp_POTR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax6.plot(Large_hydro_pp_POTR_cum[day:end].index,Large_hydro_pp_POTR_cum[day:end].values,'#0000cd', alpha=0.2)
ax6.plot(Small_hydro_pp_POTR_cum[day:end].index,Small_hydro_pp_POTR_cum[day:end].values,'#6495ed', alpha=0.2)
ax6.plot(Solar_pp_uyuni_POTR_cum[day:end].index,Solar_pp_uyuni_POTR_cum[day:end].values,'#ffd700', alpha=0.2)
ax6.plot(INTNTL_fromCOCR_POTR_cum[day:end].index,INTNTL_fromCOCR_POTR_cum[day:end].values,'#e0ffff', alpha=0.2)
ax6.plot(INTNTL_fromORUR_POTR_cum[day:end].index,INTNTL_fromORUR_POTR_cum[day:end].values,'#fff0f5', alpha=0.2)
ax6.plot(INTNTL_fromCHUR_POTR_cum[day:end].index,INTNTL_fromCHUR_POTR_cum[day:end].values,'#ffaeb9', alpha=0.2)
ax6.plot(INTNTL_fromTAJR_POTR_cum[day:end].index,INTNTL_fromTAJR_POTR_cum[day:end].values,'#b0c4de', alpha=0.2)


# negative side #

ax6.plot(INTNTL_toORUR_POTR_cum[day:end].index,INTNTL_toORUR_POTR_cum[day:end].values,'#ff69b4', alpha=0.2)
ax6.plot(INTNTL_toCHUR_POTR_cum[day:end].index,INTNTL_toCHUR_POTR_cum[day:end].values,'#98fb98', alpha=0.2)
ax6.plot(INTNTL_toTAJR_POTR_cum[day:end].index,INTNTL_toTAJR_POTR_cum[day:end].values,'#cdcd00', alpha=0.2)
ax6.plot(INTNTL_toCOCR_POTR_cum[day:end].index,INTNTL_toCOCR_POTR_cum[day:end].values,'#00fa9a', alpha=0.2)

ax6.set_ylabel('Power (GW)',labelpad = 11)

ax6.margins(x=0)
ax6.margins(y=0)

# Fill #

ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,0,Large_hydro_pp_POTR_cum_SRS[day:end].values,facecolor = '#0000cd', alpha = 0.6, label = 'Large Hydro')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,Large_hydro_pp_POTR_cum_SRS[day:end].values,Small_hydro_pp_POTR_cum_SRS[day:end].values,facecolor = '#6495ed', alpha = 0.6, label = 'Small Hydro')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,Small_hydro_pp_POTR_cum_SRS[day:end].values,OCGT_pp_POTR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,OCGT_pp_POTR_cum_SRS[day:end].values,Solar_pp_uyuni_POTR_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar Uyuni')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,Solar_pp_uyuni_POTR_cum_SRS[day:end].values,INTNTL_fromCOCR_POTR_cum_SRS[day:end].values,facecolor = '#e0ffff', alpha = 0.6, label = 'Import from COCR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_fromCOCR_POTR_cum_SRS[day:end].values,INTNTL_fromORUR_POTR_cum_SRS[day:end].values,facecolor = '#fff0f5', alpha = 0.6, label = 'Import from ORUR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_fromORUR_POTR_cum_SRS[day:end].values,INTNTL_fromCHUR_POTR_cum_SRS[day:end].values,facecolor = '#ffaeb9', alpha = 0.6, label = 'Import from CHUR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_fromCHUR_POTR_cum_SRS[day:end].values,INTNTL_fromTAJR_POTR_cum_SRS[day:end].values,facecolor = '#b0c4de', alpha = 0.6, label = 'Import from TAJR')

ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,0,INTNTL_toCOCR_POTR_cum_SRS[day:end].values,facecolor = '#00fa9a', alpha = 0.6, label = 'Export to COCR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_toCOCR_POTR_cum_SRS[day:end].values,INTNTL_toORUR_POTR_cum_SRS[day:end].values,facecolor = '#ff69b4', alpha = 0.6, label = 'Export to ORUR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_toORUR_POTR_cum_SRS[day:end].values,INTNTL_toCHUR_POTR_cum_SRS[day:end].values,facecolor = '#98fb98', alpha = 0.6, label = 'Export to CHUR')
ax6.fill_between(Large_hydro_pp_POTR_cum[day:end].index,INTNTL_toCHUR_POTR_cum_SRS[day:end].values,INTNTL_toTAJR_POTR_cum_SRS[day:end].values,facecolor = '#cdcd00', alpha = 0.6, label = 'Export to TAJR')

ax6.set_ylabel('Power (GW)',labelpad = 11)

ax6.margins(x=0)
ax6.margins(y=0)

ax6.set_title('POTR', size = 20)  


### CHUQUISACA REGION - CHUR ###

OCGT_pp_CHUR_cum = OCGT_pp_CHUR/1000000
Dual_Fuel_pp_CHUR_cum = OCGT_pp_CHUR_cum + Dual_Fuel_pp_CHUR/1000000
INTNTL_fromCOCR_CHUR_cum = Dual_Fuel_pp_CHUR_cum + INTNTL_fromCOCR_CHUR/1000000
INTNTL_fromPOTR_CHUR_cum = INTNTL_fromCOCR_CHUR_cum + INTNTL_fromPOTR_CHUR/1000000
INTNTL_toCOCR_CHUR_cum = INTNTL_toCOCR_CHUR/1000000
INTNTL_toPOTR_CHUR_cum = INTNTL_toCOCR_CHUR_cum + INTNTL_toPOTR_CHUR/1000000

OCGT_pp_CHUR_cum_SRS = OCGT_pp_CHUR_cum.squeeze()
Dual_Fuel_pp_CHUR_cum_SRS = Dual_Fuel_pp_CHUR_cum.squeeze()
INTNTL_fromCOCR_CHUR_cum_SRS = INTNTL_fromCOCR_CHUR_cum.squeeze()
INTNTL_fromPOTR_CHUR_cum_SRS = INTNTL_fromPOTR_CHUR_cum.squeeze()
INTNTL_toCOCR_CHUR_cum_SRS = INTNTL_toCOCR_CHUR_cum.squeeze()
INTNTL_toPOTR_CHUR_cum_SRS = INTNTL_toPOTR_CHUR_cum.squeeze()

# positive side #
ax7.plot(demand_CHUR_cum[day:end].index,demand_CHUR_cum[day:end].values,'#000000')
ax7.plot(OCGT_pp_CHUR_cum[day:end].index,OCGT_pp_CHUR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax7.plot(Dual_Fuel_pp_CHUR_cum[day:end].index,Dual_Fuel_pp_CHUR_cum[day:end].values,'#daa520', alpha=0.2)
ax7.plot(INTNTL_fromCOCR_CHUR_cum[day:end].index,INTNTL_fromCOCR_CHUR_cum[day:end].values,'#e0ffff', alpha=0.2)
ax7.plot(INTNTL_fromPOTR_CHUR_cum[day:end].index,INTNTL_fromPOTR_CHUR_cum[day:end].values,'#bdfcc9', alpha=0.2)
ax7.plot(INTNTL_toCOCR_CHUR_cum[day:end].index,INTNTL_toCOCR_CHUR_cum[day:end].values,'#00fa9a', alpha=0.2)
ax7.plot(INTNTL_toPOTR_CHUR_cum[day:end].index,INTNTL_toPOTR_CHUR_cum[day:end].values,'#cd853f', alpha=0.2)

ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,0,OCGT_pp_CHUR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,OCGT_pp_CHUR_cum_SRS[day:end].values,Dual_Fuel_pp_CHUR_cum_SRS[day:end].values,facecolor = '#daa520', alpha = 0.6, label = 'Dual Fuel')
ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,Dual_Fuel_pp_CHUR_cum_SRS[day:end].values,INTNTL_fromCOCR_CHUR_cum_SRS[day:end].values,facecolor = '#e0ffff', alpha = 0.6, label = 'Import from COCR')
ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,INTNTL_fromCOCR_CHUR_cum_SRS[day:end].values,INTNTL_fromPOTR_CHUR_cum_SRS[day:end].values,facecolor = '#bdfcc9', alpha = 0.6, label = 'Import from POTR')
ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,0,INTNTL_toCOCR_CHUR_cum_SRS[day:end].values,facecolor = '#00fa9a', alpha = 0.6, label = 'Export to COCR')
ax7.fill_between(OCGT_pp_CHUR_cum[day:end].index,INTNTL_toCOCR_CHUR_cum_SRS[day:end].values,INTNTL_toPOTR_CHUR_cum_SRS[day:end].values,facecolor = '#cd853f', alpha = 0.6, label = 'Export to POTR')

ax7.set_ylabel('Power (GW)',labelpad = 11)

ax7.margins(x=0)
ax7.margins(y=0)

ax7.set_title('CHUR', size = 20)  

### TARIJA REGION - TAJR ###

Small_hydro_pp_TAJR_cum = Small_hydro_pp_TAJR/1000000
OCGT_pp_TAJR_cum = Small_hydro_pp_TAJR_cum + OCGT_pp_TAJR/1000000
CCGT_pp_TAJR_cum = OCGT_pp_TAJR_cum + CCGT_pp_TAJR/1000000
Solar_pp_yunchara_TAJR_cum = CCGT_pp_TAJR_cum + Solar_pp_yunchara_TAJR/1000000
INTNTL_fromPOTR_TAJR_cum = Solar_pp_yunchara_TAJR_cum + INTNTL_fromPOTR_TAJR/1000000
INTNTL_toPOTR_TAJR_cum = INTNTL_toPOTR_TAJR/1000000

OCGT_pp_TAJR_cum_SRS = OCGT_pp_TAJR_cum.squeeze()
CCGT_pp_TAJR_cum_SRS = CCGT_pp_TAJR_cum.squeeze()
Small_hydro_pp_TAJR_cum_SRS = Small_hydro_pp_TAJR_cum.squeeze()
Solar_pp_yunchara_TAJR_cum_SRS = Solar_pp_yunchara_TAJR_cum.squeeze()
INTNTL_fromPOTR_TAJR_cum_SRS = INTNTL_fromPOTR_TAJR_cum.squeeze()
INTNTL_toPOTR_TAJR_cum_SRS = INTNTL_toPOTR_TAJR_cum.squeeze()
# positive side #

ax8.plot(demand_TAJR_cum[day:end].index,demand_TAJR_cum[day:end].values,'#000000')
ax8.plot(OCGT_pp_TAJR_cum[day:end].index,OCGT_pp_TAJR_cum[day:end].values,'#c1cdcd', alpha=0.2)
ax8.plot(CCGT_pp_TAJR_cum[day:end].index,CCGT_pp_TAJR_cum[day:end].values,'#8c000f', alpha=0.2)
ax8.plot(Small_hydro_pp_TAJR_cum[day:end].index,Small_hydro_pp_TAJR_cum[day:end].values,'#6495ed', alpha=0.2)
ax8.plot(Solar_pp_yunchara_TAJR_cum[day:end].index,Solar_pp_yunchara_TAJR_cum[day:end].values,'#ffd700', alpha=0.2)
ax8.plot(INTNTL_fromPOTR_TAJR_cum[day:end].index,INTNTL_fromPOTR_TAJR_cum[day:end].values,'#bdfcc9', alpha=0.2)
ax8.plot(INTNTL_toPOTR_TAJR_cum[day:end].index,INTNTL_toPOTR_TAJR_cum[day:end].values,'#cd853f', alpha=0.2)


ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,0,Small_hydro_pp_TAJR_cum_SRS[day:end].values,facecolor = '#6495ed', alpha = 0.6, label = 'Small Hydro')
ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,Small_hydro_pp_TAJR_cum_SRS[day:end].values,OCGT_pp_TAJR_cum_SRS[day:end].values,facecolor = '#c1cdcd', alpha = 0.6, label = 'OCGT')
ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,OCGT_pp_TAJR_cum_SRS[day:end].values,CCGT_pp_TAJR_cum_SRS[day:end].values,facecolor = '#8c000f', alpha = 0.6, label = 'CCGT')
ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,CCGT_pp_TAJR_cum_SRS[day:end].values,Solar_pp_yunchara_TAJR_cum_SRS[day:end].values,facecolor = '#ffd700', alpha = 0.6, label = 'Solar Yunchara')
ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,Solar_pp_yunchara_TAJR_cum_SRS[day:end].values,INTNTL_fromPOTR_TAJR_cum_SRS[day:end].values,facecolor = '#bdfcc9', alpha = 0.6, label = 'Import from POTR')
ax8.fill_between(Small_hydro_pp_TAJR_cum[day:end].index,0,INTNTL_toPOTR_TAJR_cum_SRS[day:end].values,facecolor = '#cd853f', alpha = 0.6, label = 'Export to POTR')

ax8.set_ylabel('Power (GW)',labelpad = 11)

ax8.margins(x=0)
ax8.margins(y=0)

ax8.set_title('TAJR', size = 20)  



p_Solar_pp_oruro = Rectangle((0, 0), 1, 1, facecolor='#ffd700')
p_Solar_pp_yunchara = Rectangle((0, 0), 1, 1, facecolor='#ffd700')
p_Solar_pp_uyuni = Rectangle((0, 0), 1, 1, facecolor="#ffd700")
p_OCGT_pp = Rectangle((0, 0), 1, 1, facecolor="#c1cdcd")
p_CCGT_pp = Rectangle((0, 0), 1, 1, facecolor="#8c000f")
p_Dual_Fuel_pp = Rectangle((0, 0), 1, 1, facecolor="#daa520")
p_ICE_pp = Rectangle((0, 0), 1, 1, facecolor="#ee6aa7")
p_Bio_pp = Rectangle((0, 0), 1, 1, facecolor="#adff2f")
p_Small_hydro_pp = Rectangle((0, 0), 1, 1, facecolor="#6495ed")
p_Large_hydro_pp = Rectangle((0, 0), 1, 1, facecolor="#0000cd")
p_Wind_pp = Rectangle((0, 0), 1, 1, facecolor='#7fffd4')
p_Nuclear_pp = Rectangle((0, 0), 1, 1, facecolor="#008000")

p_Import_BENR = Rectangle((0, 0), 1, 1, fc="#e6e6fa")
p_Import_SCZR = Rectangle((0, 0), 1, 1, fc="#ab82ff")
p_Import_LPZR = Rectangle((0, 0), 1, 1, fc="#ffefdb")
p_Import_ORUR = Rectangle((0, 0), 1, 1, fc="#fff0f5")
p_Import_POTR = Rectangle((0, 0), 1, 1, fc="#bdfcc9")
p_Import_COCR = Rectangle((0, 0), 1, 1, fc="#e0ffff")
p_Import_CHUR = Rectangle((0, 0), 1, 1, fc="#ffaeb9")
p_Import_TAJR = Rectangle((0, 0), 1, 1, fc="#b0c4de")

p_Export_BENR = Rectangle((0, 0), 1, 1, fc="#9370db")
p_Export_SCZR = Rectangle((0, 0), 1, 1, fc="#ee7942")
p_Export_LPZR = Rectangle((0, 0), 1, 1, fc="#adff2f")
p_Export_ORUR = Rectangle((0, 0), 1, 1, fc="#ff69b4")
p_Export_POTR = Rectangle((0, 0), 1, 1, fc="#cd853f")
p_Export_COCR = Rectangle((0, 0), 1, 1, fc="#00fa9a")
p_Export_CHUR = Rectangle((0, 0), 1, 1, fc="#98fb98")
p_Export_TAJR = Rectangle((0, 0), 1, 1, fc="#cdcd00")

OCGT_pp_Label = 'OCGT'
CCGT_pp_Label = 'CCGT'
Dual_Fuel_pp_Label = 'Dual Fuel'
ICE_pp_Label = 'ICE'
Bio_pp_Label = 'Biomass'
Solar_pp_oruro_Label = 'Solar Oruro'
Solar_pp_yunchara_Label = 'Solar Yunchara'
Solar_pp_uyuni_Label = 'Solar Uyuni'
Small_hydro_pp_Label = 'Small Hydro'
Large_hydro_pp_Label = 'Large Hydro'
Wind_pp_Label = 'Wind'
Nuclear_pp_Label = 'Nuclear'
Import_BENR_Label = 'Import from BENR'
Import_SCZR_Label = 'Import from SCZR'
Import_LPZR_Label = 'Import from LPZR'
Import_ORUR_Label = 'Import from ORUR'
Import_POTR_Label = 'Import from POTR'
Import_COCR_Label = 'Import from COCR'
Import_CHUR_Label = 'Import from CHUR'
Import_TAJR_Label = 'Import from TAJR'
Export_BENR_Label = 'Export to BENR'
Export_SCZR_Label = 'Export to SCZR'
Export_LPZR_Label = 'Export to LPZR'
Export_ORUR_Label = 'Export to ORUR'
Export_POTR_Label = 'Export to POTR'
Export_COCR_Label = 'Export to COCR'
Export_CHUR_Label = 'Export to CHUR'
Export_TAJR_Label = 'Export to TAJR'


plt.legend([p_OCGT_pp, p_CCGT_pp, p_Dual_Fuel_pp, p_ICE_pp, p_Bio_pp, p_Small_hydro_pp, p_Large_hydro_pp, p_Wind_pp, p_Solar_pp_oruro, p_Solar_pp_yunchara, p_Solar_pp_uyuni, p_Nuclear_pp,p_Import_BENR, p_Import_SCZR, p_Import_LPZR, p_Import_ORUR, p_Import_POTR, p_Import_COCR, p_Import_CHUR, p_Import_TAJR, p_Export_BENR, p_Export_SCZR, p_Export_LPZR, p_Export_ORUR, p_Export_POTR, p_Export_COCR, p_Export_CHUR, p_Export_TAJR ], 
           [OCGT_pp_Label, CCGT_pp_Label, Dual_Fuel_pp_Label, ICE_pp_Label, Bio_pp_Label, Solar_pp_oruro_Label, Solar_pp_yunchara_Label, Solar_pp_uyuni_Label, Small_hydro_pp_Label, Large_hydro_pp_Label, Wind_pp_Label, Nuclear_pp_Label,Import_BENR_Label ,Import_SCZR_Label, Import_LPZR_Label, Import_ORUR_Label, Import_POTR_Label, Import_COCR_Label, Import_CHUR_Label, Import_TAJR_Label, Export_BENR_Label, Export_SCZR_Label, Export_LPZR_Label, Export_ORUR_Label, Export_POTR_Label, Export_COCR_Label, Export_CHUR_Label, Export_TAJR_Label],
           bbox_to_anchor=(1.4, 2.22))

# %% [markdown]
# ### 6. Visualizing the results by the inner functions of the built-in graph class

# %%
my_graphs.node_pie(rational = 'consumption', kind='absolute', unit = 'GWh')

# %%
model.plot.pie(kind='absolute', unit = 'GWh')

# %%
my_graphs.sys_dispatch()

# %%
my_graphs.ins_cap_plot()
